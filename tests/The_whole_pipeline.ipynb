# %% [markdown]
# # Generation of the distance matrice and its euclidean space transformation

# %% [markdown]
# This is the first part of the pipeline, where the data is preprocessed, distance matrice is generated and transformed into a coordinate matrice with a help of an MDS procedure, implemented in R.
#
# The data preprocessing includes labels (Y) and features (X) generation in a form of 1d and 2d numpy arrays respectively.
#
# The distance matrice is obtained from the performances of each of the feature subsets on the cross-validation data set. The intrasubset distances are obtained based on the feature_importance parameter of Decision Tree classifier, sklearn implementation.

# %% [markdown]
# # Importing all the necessary modules

# %%
import pandas as pd
import os
import sys
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import PconvNetPolimi as pcnp
# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = (20.0, 40.0)
matplotlib.rcParams['font.size'] = 22
matplotlib.rcParams['xtick.labelsize'] = 22
matplotlib.rcParams['ytick.labelsize'] = 22
matplotlib.rcParams['axes.labelsize'] = 30
matplotlib.rcParams['axes.titlesize'] = 30

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Making the results reproducible

# %%
seed = 42
np.random.seed(seed)

# %% [markdown]
# # rpy2 module allows on usage of R inside of python

# %%
import rpy2
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
import rpy2.robjects.numpy2ri
rpy2.robjects.numpy2ri.activate()
sma = importr('smacof')

# %% [markdown]
# # Initialization of all the required parameters

# %%
num_iters = 20 #number of iterations for finding the most optimal subset of features. 
#the subset is then subtracted from the list of available features and the operation is repeated 
population_subset_size = 100 #number of features to be chosen
num_of_top_to_choose = 1
top_k = 500 # feature selectrion procedure, where top k features based on chi2 test are taken
#tads = True #set to True if you want to work with tads set of genes

# %%
path = "/home/nanni/Projects/ML/TAD_Trento/all_tcga_TAD.tsv"
X_train, X_test, Y_train, Y_test, top_inds = pcnp.get_raw_data(path, top_k, tads=False)
X_train, X_cv, Y_train, Y_cv = train_test_split(X_train,Y_train,test_size=0.3)

# %% [markdown]
# # Data tissue-invariant genes

# %% [markdown]
# # Getting the MDS representation of the distance matrix

# %%
scores, ranks, inds = pcnp.cluster_generator_new(X_train, Y_train, num_iters, population_subset_size, 
                                            top_k, 5,num_of_top_to_choose)
dist_final = pcnp.get_distance_matrix(scores, inds, ranks, X_train.shape[1])
R_mds = np.array(sma.torgerson(dist_final, p = 25))
# Out:
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # Loading multiple MDS matrices

# %%
# m_d_m = np.zeros((X_train.shape[1],25,10),float)
# for i in range(0,10):
#     m_d_m[:,:,i] = np.load('dist_m_100_iter_'+str(i+2)+'.npy')
# # for i in range(10,20):
# #     m_d_m[:,:,i] = np.load('dist_m_200_iter_'+str(i+2-10)+'.npy')

# %% [markdown]
# ## Obtaining subsets and their scores, building a distance matrice on its basis, applying MDS, checking the preservation of the nearest neighbors

# %%
#scores, ranks, inds = cluster_generator_wrapper_subsets(X_train, Y_train, num_iters, subset_size, top_k)
# Out:
# /home/sakalouski/.conda/envs/artur/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#dist_final = get_distance_matrix(scores, inds, ranks, X_train.shape[1])
#R_mds = np.array(sma.torgerson(dist_final, p = 25))

# %%
preservation = pcnp.check_preservation_of_dims(R_mds.T, dist_final, 5)
#subset_size is number of nearest neighbors
print(preservation)
# Out:
# Computing distances in MDSres
# Finding nearest neighbors
# 0.81

# %% [markdown]
# ## Getting the disntaces from the TADs distance matrix for top_k genes

# %%
# path_MDS = '/home/sakalouski/TAD_Trento/distance matrices/MDSes/interTADs_dists_all_15k.csv'
# R_mds = pd.read_csv(path_MDS, header = None).as_matrix()

# %%
# R_mds_selected = R_mds[top_inds,:]

# %% [markdown]
# # Second part of the pipeline - DL setup

# %% [markdown]
# ## Imports

# %%
from keras import backend as K
import tensorflow as tf
config = tf.ConfigProto(device_count = {'CPU': 1}, intra_op_parallelism_threads=7, inter_op_parallelism_threads=1)
session = tf.Session(config=config)
K.set_session(session)
import keras

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from phcnn.layers import PhyloConv1D, euclidean_distances
# Out:
# Using TensorFlow backend.

# %%
batch_size = 100
nb_filters = 5
nb_neighbors = 5
model_name = 'test_pub_data'

# %% [markdown]
# # Load the coordinates matrice in case of using an external one

# %%
#R_mds = np.load('test.npy')

# %% [markdown]
# ## Reshaping MDS represenation

# %%
MDSmat = pcnp.mds_reshape(R_mds, batch_size)

# %% [markdown]
# # Reshaping multiple MDS matrices

# %%
MDSmat.shape
# Out:
# (100, 25, 336, 1)

# %%
MDSmat_multi = np.zeros((int(batch_size),25,top_k,10),float)
for i in range(0,10):
    MDSmat_multi[:,:,:,[i]] = pcnp.mds_reshape(m_d_m[:,:,i], int(batch_size))
#     temp = np.zeros_like(MDSmat_multi[:,:,:,[i]])
#     temp = MDSmat_multi[:,:,:,[i]]
#     temp.flatten()
#     np.random.shuffle(temp)
#     temp = temp.reshape(MDSmat_multi.shape[0],MDSmat_multi.shape[1],MDSmat_multi.shape[2],1)
#     MDSmat_multi[:,:,:,[i]] = temp

# %% [markdown]
# # Reshaping X and Y to the suitable form

# %%
Y_input_test = keras.utils.to_categorical(Y_test, num_classes=None)
Y_input_train = keras.utils.to_categorical(Y_train, num_classes=None)
Y_input_cv = keras.utils.to_categorical(Y_cv, num_classes=None)

X_test_inp = X_test.reshape(X_test.shape[0],X_test.shape[1],-1)
X_train_inp = X_train.reshape(X_train.shape[0],X_train.shape[1],-1)
X_cv_inp = X_cv.reshape(X_cv.shape[0],X_train.shape[1],-1)

# %%
Y_input_train.shape
# Out:
# (5569, 15)

# %% [markdown]
# # Upsampling

# %%
X_train_inp, Y_input_train = pcnp.upsampling(X_train_inp, Y_input_train)

# %% [markdown]
# # Creating and training the model. Validation loss is printed

# %%
model = pcnp.create_model(X_train_inp, Y_input_train, MDSmat, nb_filters, nb_neighbors, which = 'phylo')
#model = create_dense_model(X_train_inp, Y_input_train)

# %%
model_trained = pcnp.train_model(model, X_train_inp, Y_input_train, batch_size, 30, 30, model_name, 
                            MDSmat, X_cv_inp, Y_input_cv, dist_matrix=True)
# Out:
# Epoch:  1
# Current val_loss is:  3.197300707545604
# Current train_loss is:  42.23400828047676
# Model Saved as: test_pub_data
# Epoch:  2
# Current val_loss is:  3.2587975612921203
# Current train_loss is:  38.261726573460145
# Epoch:  3
# Current val_loss is:  2.896791884123258
# Current train_loss is:  37.3479758730232
# Model Saved as: test_pub_data
# Epoch:  4
# Current val_loss is:  2.699976496450441
# Current train_loss is:  36.375291643506955
# Model Saved as: test_pub_data
# Epoch:  5
# Current val_loss is:  2.6390926511817137
# Current train_loss is:  35.99009032112951
# Model Saved as: test_pub_data
# Epoch:  6
# Current val_loss is:  2.634307134781441
# Current train_loss is:  35.42646355306158
# Model Saved as: test_pub_data
# Epoch:  7
# Current val_loss is:  2.6547172171738187
# Current train_loss is:  35.13984458125785
# Epoch:  8
# Current val_loss is:  2.5731258948320757
# Current train_loss is:  34.954178997721456
# Model Saved as: test_pub_data
# Epoch:  9
# Current val_loss is:  2.5864049080521685
# Current train_loss is:  34.71002051746833
# Epoch:  10
# Current val_loss is:  2.577994186019591
# Current train_loss is:  34.50773783766589
# Epoch:  11
# Current val_loss is:  2.6005505027473976
# Current train_loss is:  34.34679002323064
# Epoch:  12
# Current val_loss is:  2.5871656767840245
# Current train_loss is:  34.23086737780354
# Epoch:  13
# Current val_loss is:  2.5739880593657682
# Current train_loss is:  34.246961409448105
# Epoch:  14
# Current val_loss is:  2.611246754736191
# Current train_loss is:  34.0817903713807
# Epoch:  15
# Current val_loss is:  2.568072714629088
# Current train_loss is:  33.94719542009144
# Model Saved as: test_pub_data
# Epoch:  16
# Current val_loss is:  2.5808839004353623
# Current train_loss is:  33.85205253270737
# Epoch:  17
# Current val_loss is:  2.5931204399263232
# Current train_loss is:  33.77746949782546
# Epoch:  18
# Current val_loss is:  2.583173506062257
# Current train_loss is:  33.800330928957315
# Epoch:  19
# Current val_loss is:  2.555809782149813
# Current train_loss is:  33.66146178899908
# Model Saved as: test_pub_data
# Epoch:  20
# Current val_loss is:  2.5950292100133865
# Current train_loss is:  33.6095157778726
# Epoch:  21
# Current val_loss is:  2.578875497201526
# Current train_loss is:  33.53900912465609
# Epoch:  22
# Current val_loss is:  2.591275813099043
# Current train_loss is:  33.48396461875556
# Epoch:  23
# Current val_loss is:  2.570876464037696
# Current train_loss is:  33.25044187705926
# Epoch:  24
# Current val_loss is:  2.568283562902421
# Current train_loss is:  33.2867359185407
# Epoch:  25
# Current val_loss is:  2.5653136055963945
# Current train_loss is:  33.21426932430184
# Epoch:  26
# Current val_loss is:  2.5786401771676637
# Current train_loss is:  33.21929039182147
# Epoch:  27
# Current val_loss is:  2.569533055166412
# Current train_loss is:  33.182833326099576
# Epoch:  28
# Current val_loss is:  2.5653647352124023
# Current train_loss is:  33.114384665708585
# Epoch:  29
# Current val_loss is:  2.584480536682723
# Current train_loss is:  33.00484531890186
# Epoch:  30
# Current val_loss is:  2.596482622604319
# Current train_loss is:  32.98833990161684
# Epoch:  31
# Current val_loss is:  2.5666928810315324
# Current train_loss is:  32.85154081514488
# Epoch:  32
# Current val_loss is:  2.561046031477744
# Current train_loss is:  32.97849335308119
# Epoch:  33
# Current val_loss is:  2.5555353885299454
# Current train_loss is:  32.83910329295691
# Model Saved as: test_pub_data
# Epoch:  34
# Current val_loss is:  2.547271528190298
# Current train_loss is:  32.81515203740131
# Model Saved as: test_pub_data
# Epoch:  35
# Current val_loss is:  2.554175344588962
# Current train_loss is:  32.65366217763256
# Epoch:  36
# Current val_loss is:  2.587323571504541
# Current train_loss is:  32.685251937852826
# Epoch:  37
# Current val_loss is:  2.5833184453817637
# Current train_loss is:  32.66600336662349
# Epoch:  38
# Current val_loss is:  2.565434567037477
# Current train_loss is:  32.62022963057636
# Epoch:  39
# Current val_loss is:  2.5529542263911504
# Current train_loss is:  32.51403417420743
# Epoch:  40
# Current val_loss is:  2.564603350948974
# Current train_loss is:  32.58231263175534
# Epoch:  41
# Current val_loss is:  2.55084158868135
# Current train_loss is:  32.415294426687694
# Epoch:  42
# Current val_loss is:  2.5446391130419177
# Current train_loss is:  32.48173840146118
# Model Saved as: test_pub_data
# Epoch:  43
# Current val_loss is:  2.585806681416443
# Current train_loss is:  32.36472200771314
# Epoch:  44
# Current val_loss is:  2.5690605071926833
# Current train_loss is:  32.40107378219363
# Epoch:  45
# Current val_loss is:  2.576624503779327
# Current train_loss is:  32.30810893151323
# Epoch:  46
# Current val_loss is:  2.588012020984523
# Current train_loss is:  32.227391947989695
# Epoch:  47
# Current val_loss is:  2.603302827985628
# Current train_loss is:  32.24563750721851
# Epoch:  48
# Current val_loss is:  2.572833944152458
# Current train_loss is:  32.1945184346126
# Epoch:  49
# Current val_loss is:  2.578134012753523
# Current train_loss is:  32.135219618080434
# Epoch:  50
# Current val_loss is:  2.589878602302883
# Current train_loss is:  32.22449732857186
# Epoch:  51
# Current val_loss is:  2.5704563622963166
# Current train_loss is:  32.09402741223143
# Epoch:  52
# Current val_loss is:  2.567700531298489
# Current train_loss is:  32.11083944101823
# Epoch:  53
# Current val_loss is:  2.5793954939955883
# Current train_loss is:  32.07085623656361
# Epoch:  54
# Current val_loss is:  2.5748740125215437
# Current train_loss is:  31.89896950928202
# Epoch:  55
# Current val_loss is:  2.5714878240437917
# Current train_loss is:  32.04804227242068
# Epoch:  56
# Current val_loss is:  2.595292914588981
# Current train_loss is:  31.874674593334838
# Epoch:  57
# Current val_loss is:  2.581091421198261
# Current train_loss is:  31.90402689566406
# Epoch:  58
# Current val_loss is:  2.5800372306517776
# Current train_loss is:  31.929112857118692
# Epoch:  59
# Current val_loss is:  2.585727802213339
# Current train_loss is:  31.841560459889806
# Epoch:  60
# Current val_loss is:  2.5744304656719406
# Current train_loss is:  31.89993393629345
# Epoch:  61
# Current val_loss is:  2.592008505765343
# Current train_loss is:  31.872311281764368
# Epoch:  62
# Current val_loss is:  2.558150961387314
# Current train_loss is:  31.81279756342069
# Epoch:  63
# Current val_loss is:  2.575553049395289
# Current train_loss is:  31.755249839243103
# Epoch:  64
# Current val_loss is:  2.5868309449361524
# Current train_loss is:  31.64852567574936
# Epoch:  65
# Current val_loss is:  2.597249134091735
# Current train_loss is:  31.686023273837595
# Epoch:  66
# Current val_loss is:  2.5769690161166743
# Current train_loss is:  31.74149026787839
# Epoch:  67
# Current val_loss is:  2.5963029151911927
# Current train_loss is:  31.716955233757105
# Epoch:  68
# Current val_loss is:  2.590617569784555
# Current train_loss is:  31.734575585366134
# Epoch:  69
# Current val_loss is:  2.5744582034373145
# Current train_loss is:  31.754214112890384
# Epoch:  70
# Current val_loss is:  2.578607882014767
# Current train_loss is:  31.59327969749943
# Epoch:  71
# Current val_loss is:  2.5765987871022413
# Current train_loss is:  31.660129308947706
# Epoch:  72
# Current val_loss is:  2.6004361773844527
# Current train_loss is:  31.474722626581688
# Epoch:  73
# Current val_loss is:  2.575999495263428
# Current train_loss is:  31.547083214760665
# New LR is:  9.999999747378752e-05

# %% [markdown]
# ## Plotting validation and training loss functions

# %%
val_loss = np.load('val_loss_'+model_name+'.npy')
train_loss = np.load('train_loss_'+model_name+'.npy')
x_axis = range(0,len(val_loss))
plt.plot(x_axis,train_loss, label='Training loss')
plt.plot(x_axis,val_loss,  label='Validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Evaluating the performance on the test set

# %%
model_trained = pcnp.create_model(X_train_inp, Y_input_train, MDSmat, nb_filters, nb_neighbors, which = 'phylo')
model_trained.load_weights(model_name+'.h5')

# %%
Y_pred = np.array(Y_input_test)
for i in range(0,Y_pred.shape[0]):
    Y_pred[i,:] = model_trained.predict(x = [X_test_inp[[i],:,:], MDSmat[1:2:,:,:]])

Y_pred_1d = pcnp.to_1d_labels(Y_pred)
rep = classification_report(Y_test,Y_pred_1d)
print(rep)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.14      0.01      0.02       172
#           1       0.17      0.18      0.18        92
#           2       0.20      0.09      0.12        81
#           3       0.11      0.05      0.07        81
#           4       0.48      0.27      0.35        77
#           5       0.00      0.00      0.00        66
#           6       0.20      0.77      0.31       205
#           7       0.20      0.04      0.07        46
#           8       0.05      0.01      0.02        69
#           9       0.00      0.00      0.00        36
#          10       0.53      0.23      0.32        74
#          11       0.61      0.27      0.37        75
#          12       0.54      0.18      0.27        73
#          13       0.00      0.00      0.00        16
#          14       0.00      0.00      0.00        36
#
# avg / total       0.23      0.22      0.17      1199
